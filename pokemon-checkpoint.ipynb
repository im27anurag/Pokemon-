# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import altair as alt

# %matplotlib inline

# %% [markdown]
# ## Reading of CSV File

# %%
pd.set_option('display.max_columns',100)
data=pd.read_csv('pokemon.csv')

data.head(10)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 6     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 7     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 8     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 9  ['Shield Dust', 'Run Away']         1.00           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# ...

# %%
data['power']=data['hp']+data['attack']+data['defense']+data['sp_attack']+data['sp_defense']+data['speed']
data['power']
# Out:
# 0      318
# 1      405
# 2      625
# 3      309
# 4      405
#       ...
# 796    570
# 797    570
# 798    570
# 799    600
# 800    600
# Name: power, Length: 801, dtype: int64

# %%
data.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 801 entries, 0 to 800
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %% [markdown]
# # Trainning and testing of data and Scatter Plot of ( Attack and HP )

# %%
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
data=data.drop_duplicates()
X = data.drop('hp', axis = 1)
y =data[['hp']]

gene=data[(data['attack']>=120)&(data['sp_attack']>=100)]



seed = 100
test_data_size = 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_data_size, random_state = seed)
train_data = pd.concat([X_train, y_train], axis = 1)
test_data = pd.concat([X_test, y_test], axis = 1)

fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(x='attack', y='hp', ci=98, data=train_data, ax=ax, color='k',scatter_kws={"s": 20,"color": "royalblue","alpha":1})
ax.set_ylabel('Attack', fontsize=15, fontname='DejaVu Sans')
ax.set_xlabel("HP", fontsize=15, fontname='DejaVu Sans')
ax.set_xlim(left=None, right=None)
ax.set_ylim(bottom=None, top=None)
ax.tick_params(axis='both', which='major', labelsize=12)
fig.tight_layout()

# %% [markdown]
# # Trainning and testing of data and Scatter Plot of ( Defense and HP )

# %%
data=data.drop_duplicates()
X = data.drop('hp', axis = 1)
y =data[['hp']]

gene=data[(data['attack']>=120)&(data['sp_attack']>=100)]



seed = 100
test_data_size = 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_data_size, random_state = seed)
train_data = pd.concat([X_train, y_train], axis = 1)
test_data = pd.concat([X_test, y_test], axis = 1)

fig, ax = plt.subplots(figsize=(10, 6))
sns.regplot(x='defense', y='hp', ci=98, data=train_data, ax=ax, color='k',scatter_kws={"s": 20,"color": "royalblue","alpha":1})
ax.set_ylabel('Defense', fontsize=15, fontname='DejaVu Sans')
ax.set_xlabel("HP", fontsize=15, fontname='DejaVu Sans')
ax.set_xlim(left=None, right=None)
ax.set_ylim(bottom=None, top=None)
ax.tick_params(axis='both', which='major', labelsize=12)
fig.tight_layout()

# %% [markdown]
# # Comparision of Attack and Defense & Attack and HP

# %%
data.hist(column=['attack','defense'] ,bins=10)
data[['attack','hp']].plot.hist(alpha=0.5,grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Total Pokemon Across Generations

# %%
data['generation'].value_counts().sort_index().plot.bar(grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Total Legendary Pokemon in All Generation

# %%
data['is_legendary'].value_counts().sort_index().plot.bar(grid=True,color=(1,0,0.7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bar Graph of Columns

# %%
data.plot.hist(subplots=True,layout=(6,6),figsize=(30,30),bins=10)
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
# ...

# %% [markdown]
# # Comparision of  HP Pokemon in all Generation

# %%
data.groupby('generation').hp.max().plot.bar(grid=True)
# Out:
# <AxesSubplot:xlabel='generation'>

# %% [markdown]
# # Comparision of  HP  by their Type1

# %%
data.groupby('type1').hp.max().plot.bar(color=(0,1,0.4),grid=True)
# Out:
# <AxesSubplot:xlabel='type1'>

# %% [markdown]
# # Comparision of  Attack  by their Type1

# %%
data.groupby('type1').attack.max().plot.bar(grid=True)
# Out:
# <AxesSubplot:xlabel='type1'>

# %% [markdown]
# # Comparision of highest power of pokemon across generation

# %%
data.groupby('generation').power.max().plot.bar(grid=True,color=(0.3,0.9,0.8))
# Out:
# <AxesSubplot:xlabel='generation'>

# %% [markdown]
# # Comparisionp of HP in Legendary Pokemon and Non-Legendary Pokemon

# %%
data.groupby('is_legendary').hp.max().plot.bar(color=(0,0,0),grid=True)
# Out:
# <AxesSubplot:xlabel='is_legendary'>

# %% [markdown]
# # Comparisionp of Attack in Legendary Pokemon and Non-Legendary Pokemon

# %%
data.groupby('is_legendary').attack.max().plot.bar(color=(0,0,0.5),grid=True)
# Out:
# <AxesSubplot:xlabel='is_legendary'>

# %% [markdown]
# # Comparision of Sp_Attack By legendary And Non- Legendary

# %%
data.groupby('is_legendary').sp_attack.max() .plot.bar(color=(1,0,1),grid=True)
# Out:
# <AxesSubplot:xlabel='is_legendary'>

# %% [markdown]
# # Comparision of Sp_defense of legendary and non-legendary

# %%
data.groupby('is_legendary').sp_defense.max() .plot.bar(color=(1,0.5,0.7),grid=True)
# Out:
# <AxesSubplot:xlabel='is_legendary'>

# %% [markdown]
# # Comparision of Sp_Attack by their Type1

# %%
data.groupby('type1').sp_attack.max() .plot.bar(grid=True)
# Out:
# <AxesSubplot:xlabel='type1'>

# %% [markdown]
# # Comparision of total power of pokemon by their type1

# %%
data.groupby('type1').power.max() .plot.bar(color=(1,0,0),grid=True)
# Out:
# <AxesSubplot:xlabel='type1'>

# %% [markdown]
# # Strongest pokemon Across Generation

# %% [markdown]
# ### Generation 1

# %%
gene=data[(data['power']>=550)&(data['generation']==1)]
print(gene['name'])
gene.head()
# Out:
# 2        Venusaur
# 5       Charizard
# 8       Blastoise
# 17        Pidgeot
# 58       Arcanine
# 64       Alakazam
# 79        Slowbro
# 93         Gengar
# 114    Kangaskhan
# 126        Pinsir
# 129      Gyarados
# 141    Aerodactyl
# 143      Articuno
# 144        Zapdos
# 145       Moltres
# 148     Dragonite
# 149        Mewtwo
# 150           Mew
# Name: name, dtype: object
#                                     abilities  against_bug  against_dark  \
# 2                 ['Overgrow', 'Chlorophyll']         1.00           1.0
# 5                    ['Blaze', 'Solar Power']         0.25           1.0
# 8                    ['Torrent', 'Rain Dish']         1.00           1.0
# 17  ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50           1.0
# 58  ['Intimidate', 'Flash Fire', 'Justified']         0.50           1.0
#
#     against_dragon  against_electric  against_fairy  against_fight  \
# 2              1.0               0.5            0.5            0.5
# ...

# %% [markdown]
# ### Generation 2

# %%
gene=data[(data['power']>=550)&(data['generation']==2)]
print(gene['name'])
gene.head()
# Out:
# 180     Ampharos
# 207      Steelix
# 211       Scizor
# 213    Heracross
# 228     Houndoom
# 242       Raikou
# 243        Entei
# 244      Suicune
# 247    Tyranitar
# 248        Lugia
# 249        Ho-Oh
# 250       Celebi
# Name: name, dtype: object
#                                    abilities  against_bug  against_dark  \
# 180                       ['Static', 'Plus']          1.0           1.0
# 207   ['Rock Head', 'Sturdy', 'Sheer Force']          0.5           1.0
# 211   ['Swarm', 'Technician', 'Light Metal']          0.5           1.0
# 213               ['Swarm', 'Guts', 'Moxie']          0.5           0.5
# 228  ['Early Bird', 'Flash Fire', 'Unnerve']          1.0           0.5
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 180             1.0               0.5            1.0            1.0
# 207             0.5               0.0            0.5            2.0
# 211             0.5               1.0            0.5            1.0
# ...

# %% [markdown]
# ### Generation 3

# %%
gene=data[(data['power']>=550)&(data['generation']==3)]
print(gene['name'])
gene.head(15)
# Out:
# 253     Sceptile
# 256     Blaziken
# 259     Swampert
# 281    Gardevoir
# 288      Slaking
# 305       Aggron
# 309    Manectric
# 318     Sharpedo
# 322     Camerupt
# 333      Altaria
# 353      Banette
# 358        Absol
# 361       Glalie
# 372    Salamence
# 375    Metagross
# 376     Regirock
# 377       Regice
# 378    Registeel
# 379       Latias
# 380       Latios
# 381       Kyogre
# 382      Groudon
# 383     Rayquaza
# 384      Jirachi
# 385       Deoxys
# Name: name, dtype: object
#                                         abilities  against_bug  against_dark  \
# 253                      ['Overgrow', 'Unburden']         2.00           1.0
# 256                      ['Blaze', 'Speed Boost']         0.25           0.5
# 259                           ['Torrent', 'Damp']         1.00           1.0
# 281         ['Synchronize', 'Trace', 'Telepathy']         1.00           1.0
# 288                                    ['Truant']         1.00           1.0
# ...

# %% [markdown]
# ### Generation 4

# %%
gene=data[(data['power']>=550)&(data['generation']==4)]
print(gene['name'])
gene.head(10)
# Out:
# 427      Lopunny
# 444     Garchomp
# 447      Lucario
# 459    Abomasnow
# 474      Gallade
# 479         Uxie
# 480      Mesprit
# 481        Azelf
# 482       Dialga
# 483       Palkia
# 484      Heatran
# 485    Regigigas
# 486     Giratina
# 487    Cresselia
# 489      Manaphy
# 490      Darkrai
# 491      Shaymin
# 492       Arceus
# Name: name, dtype: object
#                                      abilities  against_bug  against_dark  \
# 427          ['Cute Charm', 'Klutz', 'Limber']         1.00           1.0
# 444                ['Sand Veil', 'Rough Skin']         1.00           1.0
# 447  ['Steadfast', 'Inner Focus', 'Justified']         0.25           0.5
# 459             ['Snow Warning', 'Soundproof']         2.00           1.0
# 474                 ['Steadfast', 'Justified']         1.00           1.0
# 479                               ['Levitate']         2.00           2.0
# 480                               ['Levitate']         2.00           2.0
# ...

# %% [markdown]
# ### Generation 5

# %%
gene=data[(data['power']>=550)&(data['generation']==5)]
print(gene['name'])
gene.head()
# Out:
# 493      Victini
# 566     Archeops
# 634    Hydreigon
# 636    Volcarona
# 637     Cobalion
# 638    Terrakion
# 639     Virizion
# 640     Tornadus
# 641    Thundurus
# 642     Reshiram
# 643       Zekrom
# 644     Landorus
# 645       Kyurem
# 646       Keldeo
# 647     Meloetta
# 648     Genesect
# Name: name, dtype: object
#                    abilities  against_bug  against_dark  against_dragon  \
# 493         ['Victory Star']         1.00           2.0             1.0
# 566            ['Defeatist']         0.50           1.0             1.0
# 634             ['Levitate']         2.00           0.5             2.0
# 636  ['Flame Body', 'Swarm']         0.50           1.0             1.0
# 637            ['Justified']         0.25           0.5             0.5
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 493               1.0            0.5            0.5           0.5
# 566               2.0            1.0            1.0           0.5
# ...

# %% [markdown]
# ### Generation 6

# %%
gene=data[(data['power']>=550)&(data['generation']==6)]
print(gene['name'])
gene.head()
# Out:
# 657     Greninja
# 669      Floette
# 670      Florges
# 705       Goodra
# 715      Xerneas
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: name, dtype: object
#                                  abilities  against_bug  against_dark  \
# 657  ['Torrent', 'Protean', 'Battle Bond']          2.0           0.5
# 669           ['Flower Veil', 'Symbiosis']          0.5           0.5
# 670           ['Flower Veil', 'Symbiosis']          0.5           0.5
# 705   ['Sap Sipper', 'Hydration', 'Gooey']          1.0           1.0
# 715                         ['Fairy Aura']          0.5           0.5
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 657             1.0               2.0            2.0            2.0
# 669             0.0               1.0            1.0            0.5
# 670             0.0               1.0            1.0            0.5
# ...

# %% [markdown]
# ### Generation 7

# %%
gene=data[(data['power']>=550)&(data['generation']==7)]
print(gene['name'])
gene.head()
# Out:
# 745    Wishiwashi
# 772      Silvally
# 783       Kommo-o
# 784     Tapu Koko
# 785     Tapu Lele
# 786     Tapu Bulu
# 787     Tapu Fini
# 790      Solgaleo
# 791        Lunala
# 792      Nihilego
# 793      Buzzwole
# 794     Pheromosa
# 795     Xurkitree
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, dtype: object
#                                      abilities  against_bug  against_dark  \
# 745                              ['Schooling']          1.0           1.0
# 772                             ['RKS System']          1.0           1.0
# 783  ['Bulletproof', 'Soundproof', 'Overcoat']          0.5           0.5
# 784            ['Electric Surge', 'Telepathy']          0.5           0.5
# 785             ['Psychic Surge', 'Telepathy']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 745             1.0               2.0            1.0           1.00
# ...

# %% [markdown]
# # Legendary Pokemon across Generation

# %% [markdown]
# ### Generation 1

# %%
gene=data[(data['is_legendary']==1)&(data['generation']==1)]
print(gene['name'])
gene.head()
# Out:
# 143    Articuno
# 144      Zapdos
# 145     Moltres
# 149      Mewtwo
# 150         Mew
# Name: name, dtype: object
#                       abilities  against_bug  against_dark  against_dragon  \
# 143  ['Pressure', 'Snow Cloak']         0.50           1.0             1.0
# 144      ['Pressure', 'Static']         0.50           1.0             1.0
# 145  ['Pressure', 'Flame Body']         0.25           1.0             1.0
# 149     ['Pressure', 'Unnerve']         2.00           2.0             1.0
# 150             ['Synchronize']         2.00           2.0             1.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 143               2.0            1.0            1.0           2.0
# 144               1.0            1.0            0.5           1.0
# 145               2.0            0.5            0.5           0.5
# 149               1.0            1.0            0.5           1.0
# 150               1.0            1.0            0.5           1.0
#
# ...

# %% [markdown]
# ### Generation 2

# %%
gene=data[(data['is_legendary']==1)&(data['generation']==2)]
print(gene['name'])
gene.head(13)
# Out:
# 242     Raikou
# 243      Entei
# 244    Suicune
# 248      Lugia
# 249      Ho-Oh
# 250     Celebi
# Name: name, dtype: object
#                        abilities  against_bug  against_dark  against_dragon  \
# 242  ['Pressure', 'Inner Focus']         1.00           1.0             1.0
# 243  ['Pressure', 'Inner Focus']         0.50           1.0             1.0
# 244  ['Pressure', 'Inner Focus']         1.00           1.0             1.0
# 248   ['Pressure', 'Multiscale']         1.00           2.0             1.0
# 249  ['Pressure', 'Regenerator']         0.25           1.0             1.0
# 250             ['Natural Cure']         4.00           2.0             1.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 242               0.5            1.0           1.00           1.0
# 243               1.0            0.5           1.00           0.5
# 244               2.0            1.0           1.00           0.5
# ...

# %% [markdown]
# ### Generation 3

# %%
gene=data[(data['is_legendary']==1)&(data['generation']==3)]
print(gene['name'])
gene.head(13)
# Out:
# 376     Regirock
# 377       Regice
# 378    Registeel
# 379       Latias
# 380       Latios
# 381       Kyogre
# 382      Groudon
# 383     Rayquaza
# 384      Jirachi
# 385       Deoxys
# Name: name, dtype: object
#                          abilities  against_bug  against_dark  against_dragon  \
# 376       ['Clear Body', 'Sturdy']          1.0           1.0             1.0
# 377     ['Clear Body', 'Ice Body']          1.0           1.0             1.0
# 378  ['Clear Body', 'Light Metal']          0.5           1.0             0.5
# 379                   ['Levitate']          2.0           2.0             2.0
# 380                   ['Levitate']          2.0           2.0             2.0
# 381                    ['Drizzle']          1.0           1.0             1.0
# 382                    ['Drought']          1.0           1.0             1.0
# 383                   ['Air Lock']          0.5           1.0             2.0
# ...

# %% [markdown]
# ### Generation 4

# %%
gene=data[(data['is_legendary']==1)&(data['generation']==4)]
print(gene['name'])
gene.head(15)
# Out:
# 479         Uxie
# 480      Mesprit
# 481        Azelf
# 482       Dialga
# 483       Palkia
# 484      Heatran
# 485    Regigigas
# 486     Giratina
# 487    Cresselia
# 489      Manaphy
# 490      Darkrai
# 491      Shaymin
# 492       Arceus
# Name: name, dtype: object
#                                  abilities  against_bug  against_dark  \
# 479                           ['Levitate']         2.00           2.0
# 480                           ['Levitate']         2.00           2.0
# 481                           ['Levitate']         2.00           2.0
# 482              ['Pressure', 'Telepathy']         0.50           1.0
# 483              ['Pressure', 'Telepathy']         1.00           1.0
# 484           ['Flash Fire', 'Flame Body']         0.25           1.0
# 485                         ['Slow Start']         1.00           1.0
# 486  ['Pressure', 'Telepathy', 'Levitate']         0.50           2.0
# 487                           ['Levitate']         2.00           2.0
# ...

# %% [markdown]
# ### Generation 5

# %%
gene=data[(data['is_legendary']==1)&(data['generation']==5)]
print(gene['name'])
gene.head(15)
# Out:
# 493      Victini
# 637     Cobalion
# 638    Terrakion
# 639     Virizion
# 640     Tornadus
# 641    Thundurus
# 642     Reshiram
# 643       Zekrom
# 644     Landorus
# 645       Kyurem
# 646       Keldeo
# 647     Meloetta
# 648     Genesect
# Name: name, dtype: object
#                                        abilities  against_bug  against_dark  \
# 493                             ['Victory Star']         1.00           2.0
# 637                                ['Justified']         0.25           0.5
# 638                                ['Justified']         0.50           0.5
# 639                                ['Justified']         1.00           0.5
# 640      ['Prankster', 'Defiant', 'Regenerator']         0.50           1.0
# 641      ['Prankster', 'Defiant', 'Volt Absorb']         0.50           1.0
# 642                               ['Turboblaze']         0.50           1.0
# 643                                 ['Teravolt']         1.00           1.0
# ...

# %% [markdown]
# ### Generation 6

# %%
gene=data[(data['is_legendary']==1)&(data['generation']==6)]
print(gene['name'])
gene.head(15)
# Out:
# 715      Xerneas
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: name, dtype: object
#                              abilities  against_bug  against_dark  \
# 715                     ['Fairy Aura']          0.5           0.5
# 716                      ['Dark Aura']          1.0           0.5
# 717  ['Aura Break', 'Power Construct']          1.0           1.0
# 718                     ['Clear Body']          0.5           0.5
# 719                       ['Magician']          1.0           4.0
# 720                   ['Water Absorb']          0.5           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 715             0.0               1.0            1.0            0.5
# 716             1.0               2.0            2.0            1.0
# 717             2.0               0.0            2.0            1.0
# 718             0.0               1.0            1.0            1.0
# ...

# %% [markdown]
# ### Generation 7

# %%
gene=data[(data['is_legendary']==1)&(data['generation']==7)]
print(gene['name'])
gene.head(20)
# Out:
# 784     Tapu Koko
# 785     Tapu Lele
# 786     Tapu Bulu
# 787     Tapu Fini
# 788        Cosmog
# 789       Cosmoem
# 790      Solgaleo
# 791        Lunala
# 792      Nihilego
# 793      Buzzwole
# 794     Pheromosa
# 795     Xurkitree
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, dtype: object
#                            abilities  against_bug  against_dark  \
# 784  ['Electric Surge', 'Telepathy']         0.50           0.5
# 785   ['Psychic Surge', 'Telepathy']         1.00           1.0
# 786    ['Grassy Surge', 'Telepathy']         1.00           0.5
# 787     ['Misty Surge', 'Telepathy']         0.50           0.5
# 788                      ['Unaware']         2.00           2.0
# 789                       ['Sturdy']         2.00           2.0
# 790              ['Full Metal Body']         1.00           2.0
# 791                ['Shadow Shield']         1.00           4.0
# ...

# %%
a=data[['hp','experience_growth','speed','base_total']].values
b=data['power'].values

# %%
from sklearn.linear_model import Lasso
X_train,X_test,Y_train,Y_test=train_test_split(a,b,test_size=0.25,random_state=123)
model22=Lasso()
model22.fit(X_train,Y_train)
print('Accuracy={}'.format(model.score(X_test,Y_test)))
# Out:
# Accuracy=1.0

# %%
lr=model.coef_

# %%
coef_df=pd.DataFrame()
coef_df['Features']=data.columns.drop(['abilities','against_bug','against_dark','against_dragon','against_electric',\
                                       'against_fairy','against_fight','against_fire','against_flying','against_ghost',\
                                       'against_grass','against_ground','against_ice','against_normal','against_poison',\
                                       'against_psychic','against_rock','against_steel','against_water','base_egg_steps',\
                                       'base_happiness','base_total','capture_rate','classfication','experience_growth',\
                                       'height_m','japanese_name','name','percentage_male','pokedex_number',\
                                       'type1','type2','weight_kg','generation','is_legendary','power'])

# %%
coef_df['coefficient']=lr
coef_df.head()
# Out:
#      Features  coefficient
# 0      attack          1.0
# 1     defense          1.0
# 2          hp          1.0
# 3   sp_attack          1.0
# 4  sp_defense          1.0

# %%
coef_df.groupby('Features').coefficient.max().plot.bar(grid=True,color=(0.3,0.9,0.8))
# Out:
# <AxesSubplot:xlabel='Features'>
